# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# **NOTA:** antes de correr las siguientes líneas de código, subir el fichero kaggle.json para establecer la conexión correctamente y descargar los csv correspondientes

# %%
os.environ['KAGGLE_CONFIG_DIR'] = '.'

# %%
# !kaggle competitions download -c udea-ai4eng-20241
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 ./kaggle.json'
# Downloading udea-ai4eng-20241.zip to /content
#  33% 7.00M/21.2M [00:00<00:00, 72.0MB/s]
# 100% 21.2M/21.2M [00:00<00:00, 136MB/s]

# %%
# !unzip udea-ai4eng-20241.zip
# Out:
# Archive:  udea-ai4eng-20241.zip
#   inflating: submission_example.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
ds = pd.read_csv('train.csv')

# %%
ds = ds.copy()
# Establecer un índice en la tabla
ds.index.name = 'ID'

# Datos de la tabla (media, mínimo, máximo, cuartiles, etc)
display(ds.describe())

print("******************************************************************")
# Filtrar por el programa académico de derecho
dx = ds[ds['ESTU_PRGM_ACADEMICO'] == 'DERECHO']
display(dx)
# Out:
#                   ID        PERIODO
# count  692500.000000  692500.000000
# mean   494606.130576   20198.366679
# std    285585.209455      10.535037
# min         1.000000   20183.000000
# 25%    247324.750000   20195.000000
# 50%    494564.500000   20195.000000
# 75%    741782.500000   20203.000000
# max    989286.000000   20213.000000
# ******************************************************************
#             ID  PERIODO ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# ID
# 1       645256    20212             DERECHO              ATLANTICO
# 15      961327    20203             DERECHO                 BOGOTÁ
# 26      925456    20195             DERECHO                BOLIVAR
# 32      347946    20212             DERECHO                  SUCRE
# 47      696248    20212             DERECHO              ANTIOQUIA
# ...        ...      ...                 ...                    ...
# 692423  680475    20212             DERECHO                 BOGOTÁ
# 692425  754069    20212             DERECHO                 TOLIMA
# 692431  212203    20212             DERECHO                 BOGOTÁ
# 692457  765817    20212             DERECHO                 BOGOTÁ
# 692493  725949    20203             DERECHO                CORDOBA
#
#                   ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# ID
# 1       Entre 2.5 millones y menos de 4 millones                       0
# 15      Entre 4 millones y menos de 5.5 millones     Entre 11 y 20 horas
# 26      Entre 2.5 millones y menos de 4 millones                     NaN
# 32      Entre 2.5 millones y menos de 4 millones                       0
# 47      Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# ...                                          ...                     ...
# 692423  Entre 4 millones y menos de 5.5 millones         Más de 30 horas
# 692425    Entre 1 millón y menos de 2.5 millones         Más de 30 horas
# 692431                         Más de 7 millones                       0
# 692457  Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 692493  Entre 2.5 millones y menos de 4 millones         Más de 30 horas
#
#        FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET  \
# ID
# 1                 Estrato 3                 No
# 15                Estrato 3                 Si
# 26                      NaN                NaN
# 32                Estrato 2                 Si
# 47                Estrato 3                 Si
# ...                     ...                ...
# 692423            Estrato 3                 Si
# 692425            Estrato 3                 Si
# 692431            Estrato 6                 Si
# 692457            Estrato 1                 No
# 692493            Estrato 1                 Si
#
#                          FAMI_EDUCACIONPADRE FAMI_TIENELAVADORA  \
# ID
# 1             Técnica o tecnológica completa                 Si
# 15            Educación profesional completa                 Si
# 26                                       NaN                NaN
# 32          Educación profesional incompleta                NaN
# 47            Técnica o tecnológica completa                 Si
# ...                                      ...                ...
# 692423      Técnica o tecnológica incompleta                 Si
# 692425  Secundaria (Bachillerato) incompleta                 Si
# 692431                             Postgrado                 Si
# 692457                               No sabe                 Si
# 692493      Educación profesional incompleta                 Si
#
#        FAMI_TIENEAUTOMOVIL ESTU_PRIVADO_LIBERTAD ESTU_PAGOMATRICULAPROPIO  \
# ID
# 1                       No                     N                       No
# 15                      Si                     N                       No
# 26                     NaN                     N                       No
# 32                     NaN                     N                       No
# 47                      No                     N                       No
# ...                    ...                   ...                      ...
# 692423                  Si                     N                       Si
# 692425                  Si                     N                       Si
# 692431                  Si                     N                       No
# 692457                  No                     N                       No
# 692493                  No                     N                       No
#
#        FAMI_TIENECOMPUTADOR FAMI_TIENEINTERNET.1  \
# ID
# 1                        Si                   No
# 15                       Si                   Si
# 26                      NaN                  NaN
# 32                      NaN                   Si
# 47                       Si                   Si
# ...                     ...                  ...
# 692423                   Si                   Si
# 692425                   Si                   Si
# 692431                   Si                   Si
# 692457                   No                   No
# 692493                   No                   Si
#
#                          FAMI_EDUCACIONMADRE RENDIMIENTO_GLOBAL
# ID
# 1           Técnica o tecnológica incompleta               bajo
# 15            Educación profesional completa               alto
# 26                                       NaN         medio-bajo
# 32            Técnica o tecnológica completa         medio-alto
# 47      Secundaria (Bachillerato) incompleta               bajo
# ...                                      ...                ...
# 692423        Técnica o tecnológica completa         medio-bajo
# 692425    Secundaria (Bachillerato) completa               bajo
# 692431                             Postgrado               bajo
# 692457        Técnica o tecnológica completa               alto
# 692493        Educación profesional completa         medio-alto
#
# [53244 rows x 17 columns]

# %%
ds = ds.copy()

# Tomar una muestra de 15 datos
smpl = ds.sample(15)
display(smpl)

print("******************************************************************")
# Gráfica de dispersión Departamento Vs Costo de matrícula (de la muestra)
smpl.plot.scatter(x = 'ESTU_PRGM_DEPARTAMENTO', y = 'ESTU_VALORMATRICULAUNIVERSIDAD')
plt.show()
# Out:
#             ID  PERIODO                                ESTU_PRGM_ACADEMICO  \
# ID
# 394786  402819    20183                                   INGENIERIA CIVIL
# 585754  762335    20183                         RELACIONES INTERNACIONALES
# 581924  460775    20212                   INGENIERIA EN TELECOMUNICACIONES
# 409936  652863    20203                                ESTUDIOS LITERARIOS
# 336266  357159    20183                 LICENCIATURA EN PEDAGOGIA INFANTIL
# 644627  223715    20212                              NUTRICION Y DIETETICA
# 110137  575220    20203  LICENCIATURA EN ETNOEDUCACION Y DESARROLLO COM...
# 692220  292673    20203                             INGENIERIA DE SISTEMAS
# 256407  902209    20195                        CIENCIA POLITICA Y GOBIERNO
# 100631  449788    20183                         ADMINISTRACIÓN DE EMPRESAS
# 388803  143320    20183                BACTERIOLOGIA Y LABORATORIO CLINICO
# 596317  260290    20195                                 INGENIERIA QUIMICA
# 228993   33091    20203                         ADMINISTRACION DE EMPRESAS
# 545712  187002    20195                                         PSICOLOGÍA
# 470748  830120    20203                              INGENIERIA INDUSTRIAL
#
#        ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# ID
# 394786              SANTANDER                          Menos de 500 mil
# 585754              ATLANTICO  Entre 5.5 millones y menos de 7 millones
# 581924                 BOGOTÁ  Entre 2.5 millones y menos de 4 millones
# 409936              ANTIOQUIA    Entre 1 millón y menos de 2.5 millones
# 336266                 BOGOTÁ    Entre 1 millón y menos de 2.5 millones
# 644627        NORTE SANTANDER                          Menos de 500 mil
# 110137              RISARALDA         Entre 500 mil y menos de 1 millón
# 692220                 BOGOTÁ  Entre 2.5 millones y menos de 4 millones
# 256407              ATLANTICO                         No pagó matrícula
# 100631                BOLIVAR    Entre 1 millón y menos de 2.5 millones
# 388803                 BOGOTÁ    Entre 1 millón y menos de 2.5 millones
# 596317        NORTE SANTANDER         Entre 500 mil y menos de 1 millón
# 228993                  CESAR         Entre 500 mil y menos de 1 millón
# 545712                 BOGOTÁ  Entre 2.5 millones y menos de 4 millones
# 470748                 BOGOTÁ    Entre 1 millón y menos de 2.5 millones
#
#        ESTU_HORASSEMANATRABAJA FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET  \
# ID
# 394786                       0            Estrato 2                 No
# 585754                       0            Estrato 2                 Si
# 581924     Entre 11 y 20 horas            Estrato 3                 Si
# 409936     Entre 21 y 30 horas          Sin Estrato                 Si
# 336266                       0            Estrato 1                 No
# 644627       Menos de 10 horas            Estrato 1                 Si
# 110137     Entre 21 y 30 horas            Estrato 2                 Si
# 692220                       0            Estrato 2                 Si
# 256407                       0            Estrato 2                 Si
# 100631     Entre 21 y 30 horas            Estrato 5                 Si
# 388803     Entre 21 y 30 horas            Estrato 2                 Si
# 596317     Entre 11 y 20 horas                  NaN                 No
# 228993         Más de 30 horas            Estrato 4                 Si
# 545712         Más de 30 horas            Estrato 3                 Si
# 470748                       0            Estrato 2                 Si
#
#                        FAMI_EDUCACIONPADRE FAMI_TIENELAVADORA  \
# ID
# 394786                             Ninguno                 No
# 585754      Técnica o tecnológica completa                 Si
# 581924  Secundaria (Bachillerato) completa                 Si
# 409936      Educación profesional completa                 Si
# 336266                   Primaria completa                 Si
# 644627                 Primaria incompleta                 Si
# 110137                 Primaria incompleta                 Si
# 692220  Secundaria (Bachillerato) completa                 Si
# 256407      Educación profesional completa                 Si
# 100631                 Primaria incompleta                 Si
# 388803      Educación profesional completa                 Si
# 596317                 Primaria incompleta                 No
# 228993      Educación profesional completa                 Si
# 545712      Educación profesional completa                 Si
# 470748                 Primaria incompleta                 Si
#
#        FAMI_TIENEAUTOMOVIL ESTU_PRIVADO_LIBERTAD ESTU_PAGOMATRICULAPROPIO  \
# ID
# 394786                  No                     N                       Si
# 585754                  Si                     N                       No
# 581924                  No                     N                       Si
# 409936                  Si                     N                       Si
# 336266                  No                     N                       No
# 644627                 NaN                     N                       No
# 110137                  No                     N                       Si
# 692220                  No                     N                       No
# 256407                  No                     N                       No
# 100631                  No                     N                       Si
# 388803                  No                     N                       No
# 596317                  No                     N                       No
# 228993                  Si                     N                       No
# 545712                  Si                     N                       Si
# 470748                  No                     N                       No
#
#        FAMI_TIENECOMPUTADOR FAMI_TIENEINTERNET.1  \
# ID
# 394786                   Si                   No
# 585754                   Si                   Si
# 581924                   Si                   Si
# 409936                   Si                   Si
# 336266                  NaN                   No
# 644627                   Si                   Si
# 110137                   Si                   Si
# 692220                   Si                   Si
# 256407                   Si                   Si
# 100631                   Si                   Si
# 388803                   Si                   Si
# 596317                   Si                   No
# 228993                   Si                   Si
# 545712                   Si                   Si
# 470748                   Si                   Si
#
#                        FAMI_EDUCACIONMADRE RENDIMIENTO_GLOBAL
# ID
# 394786                             Ninguno               alto
# 585754      Técnica o tecnológica completa               alto
# 581924  Secundaria (Bachillerato) completa         medio-alto
# 409936      Educación profesional completa               bajo
# 336266                 Primaria incompleta               bajo
# 644627                 Primaria incompleta         medio-bajo
# 110137      Técnica o tecnológica completa               alto
# 692220      Técnica o tecnológica completa               bajo
# 256407      Educación profesional completa               alto
# 100631                 Primaria incompleta         medio-bajo
# 388803      Educación profesional completa               alto
# 596317                 Primaria incompleta         medio-alto
# 228993      Técnica o tecnológica completa         medio-bajo
# 545712      Técnica o tecnológica completa         medio-alto
# 470748                 Primaria incompleta         medio-alto
# ******************************************************************

# %%
ds = ds.copy()

# Gráfico de pastel (o pie) para el estrato socieconómico de todos los estudiantes
pie = ds.FAMI_ESTRATOVIVIENDA.value_counts()
pie.plot.pie(autopct='%1.1f%%', labeldistance=0.95)
plt.show()

print("*****************************************************************")
# Conteo de cantidad de estudiantes para cada programa académico
dx = ds.ESTU_PRGM_ACADEMICO.value_counts()
display(dx)
# Out:
# *****************************************************************
# DERECHO                                                   53244
# ADMINISTRACION DE EMPRESAS                                51902
# CONTADURIA PUBLICA                                        39664
# PSICOLOGIA                                                31932
# INGENIERIA INDUSTRIAL                                     28481
#                                                           ...
# LICENCIATURA EN ESPAÑOL Y FILOLOGÍA                           1
# ADMINISTRACION EN NEGOCIOS INTERNACIONALES                    1
# ADMINISTRACION DE COMERCIO EXTERIOR                           1
# LICENCIATURA EN EDUCACI¿N F¿SICA RECREACI¿N Y DEPORTES        1
# PROFESIONAL EN INVESTIGACIÓN CRIMINAL                         1
# Name: ESTU_PRGM_ACADEMICO, Length: 948, dtype: int64
